# %%
! nvidia-smi
! pip -q install tensorflow-io
# Out:
# Tue Jun 22 05:29:27 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 465.27       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla P100-PCIE...  Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P0    28W / 250W |      0MiB / 16280MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+
#      |████████████████████████████████| 24.1MB 1.6MB/s
#      |████████████████████████████████| 2.5MB 41.1MB/s

# %% [markdown]
# # Introduction
# In this kernel we will attempt to reproduce a minimal version of [Instance-aware Image Colorization](https://arxiv.org/abs/2005.10825) by Jheng-Wei Su et. al. The authors suggest a three way architecture for colorization.
#
# - Full image colorization
# - Instance colorization
# - Fusion module
#
# This is a minimal implementation of the paper where I have made some essential changes:
# - Using RGB color space instead of L\*a\*b\* color space.
# - Using the bbox provided by the dataset used, instead of using a pretrained Object Detector model to derive the bbox (this step takes a lot of time to implement).
# - Changing the U-Net architecture and training it E2E instead of using a pretrained model and then using transfer learning.

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
tfds.disable_progress_bar()

import matplotlib.pyplot as plt
plt.style.use('dark_background')
import numpy as np

from tqdm.notebook import tqdm

import tensorflow_io as tfio

# %% [markdown]
# We are going to use the PASCAL VOC dataset. The idea here is to keep an original dataset at hand and change the dataset as we move along the procedures.

# %%
ori_train_ds = tfds.load('voc', split='train')
ori_test_ds = tfds.load('voc', split='validation')
# Out:
# Downloading and preparing dataset voc/2007/4.0.0 (download: 868.85 MiB, generated: Unknown size, total: 868.85 MiB) to /root/tensorflow_datasets/voc/2007/4.0.0...
# Shuffling and writing examples to /root/tensorflow_datasets/voc/2007/4.0.0.incomplete63NNCF/voc-test.tfrecord
# Shuffling and writing examples to /root/tensorflow_datasets/voc/2007/4.0.0.incomplete63NNCF/voc-train.tfrecord
# Shuffling and writing examples to /root/tensorflow_datasets/voc/2007/4.0.0.incomplete63NNCF/voc-validation.tfrecord
# Dataset voc downloaded and prepared to /root/tensorflow_datasets/voc/2007/4.0.0. Subsequent calls will reuse this data.

# %%
# Util function for lab to rgb conversion
def lab_rgb(l, ab):
    l = (l + 1.0)* 50.0
    ab = ab * 110.0

    lab = tf.concat([l,ab], axis=-1)
    rgb = tfio.experimental.color.lab_to_rgb(lab)
    return rgb

# %% [markdown]
# ## First Stage
# In the first stage we go for the total image colorization. We build a U-Net and try colorizing the entire image at a go.
#
# The loss proposed by the authors is similar to the one used by Zhang et. al. (Real- time user-guided image colorization with learned deep priors).
# $$
# l_{\delta}(x,y)=\frac{1}{2}(x-y)^2\mathbb{1}_{\{|x-y|<\delta\}}+\delta(|x-y|-\frac{1}{2}\delta)\mathbb{1}_{\{|x-y|\geqslant{\delta}\}}
# $$
#
# The loss function $l_\delta$ is evaluated at each pixel and summed together to evaluate the loss $\mathcal{L}$ for a whole image.
# $$
# \mathcal{L}=\sum_{h,w}\sum_{q}(l_{\delta})
# $$

# %% [markdown]
# ### Dataset
# At each stage we need to mould the original dataset a bit. Here we will preprocess the image. The preprocessing stage consists of:
# - Resizing the images to 256,256
# - Converting the dtype from uint8 to float32
# - Scaling the images to 0 to 1

# %%
def preprocess_one(element):
    # Convert the dtype of images from uint8 to float32
    image = tf.image.convert_image_dtype(element['image'], tf.float32)
    # resize the image to 256, 256
    image = tf.image.resize(image, (256, 256))
    # convert the rgb color space to lab
    lab = tfio.experimental.color.rgb_to_lab(image)
    l = lab[...,0]/50.0 - 1.0
    ab = lab[...,1:]/110.0
    
    l = tf.expand_dims(l, axis=-1)

    return l, ab

# %%
one_train_ds = ori_train_ds.map(preprocess_one).shuffle(32).batch(32)

l_batch, ab_batch = next(iter(one_train_ds))
print(l_batch.shape)
print(ab_batch.shape)
# Out:
# (32, 256, 256, 1)
# (32, 256, 256, 2)

# %%
print("l")
print(f"  [SHAPE]: {l_batch.shape}")
print(f"  [MIN]:{tf.math.reduce_min(l_batch)}")
print(f"  [MEAN]:{tf.math.reduce_mean(l_batch)}")
print(f"  [MAX]:{tf.math.reduce_max(l_batch)}")


print("ab")
print(f"  [SHAPE]: {ab_batch.shape}")
print(f"  [MIN]:{tf.math.reduce_min(ab_batch)}")
print(f"  [MEAN]:{tf.math.reduce_mean(ab_batch)}")
print(f"  [MAX]:{tf.math.reduce_max(ab_batch)}")
# Out:
# l
#   [SHAPE]: (32, 256, 256, 1)
#   [MIN]:-1.0
#   [MEAN]:-0.06679936498403549
#   [MAX]:1.0
# ab
#   [SHAPE]: (32, 256, 256, 2)
#   [MIN]:-0.7217676043510437
#   [MEAN]:0.041810765862464905
#   [MAX]:0.8136052489280701

# %% [markdown]
# ### U-Net
# We will be using a U-Net architecture for colorization. It has been seen that architectures of this sort helps in synthesis of images.

# %%
def downsample(input_shape, filter, i):
    # input_shape = (H,W,C)
    model = tf.keras.Sequential(name=f"downsample_{i}")
    model.add(tf.keras.layers.Conv2D(
        filters=input_shape[-1],
        kernel_size=3,
        strides=1,
        padding='same',))
    model.add(tf.keras.layers.PReLU())
    model.add(tf.keras.layers.Conv2D(
        filters=input_shape[-1],
        kernel_size=3,
        strides=1,
        padding='same',))
    model.add(tf.keras.layers.PReLU())
    model.add(tf.keras.layers.Conv2D(
        filters=input_shape[-1],
        kernel_size=3,
        strides=1,
        padding='same',))
    model.add(tf.keras.layers.PReLU())
    model.add(tf.keras.layers.Conv2D(
        filters=filter,
        kernel_size=3,
        strides=2,
        padding='same',))
    model.add(tf.keras.layers.PReLU())

    return model

# %%
def upsample(input_shape, filter, i):
    # input_shape = (H,W,C)
    model = tf.keras.Sequential(name=f"upsample_{i}")
    model.add(tf.keras.layers.Conv2D(
        filters=input_shape[-1],
        kernel_size=3,
        strides=1,
        padding='same',))
    model.add(tf.keras.layers.PReLU())
    model.add(tf.keras.layers.Conv2D(
        filters=input_shape[-1],
        kernel_size=3,
        strides=1,
        padding='same',))
    model.add(tf.keras.layers.PReLU())
    
    model.add(tf.keras.layers.Conv2D(
        filters=input_shape[-1],
        kernel_size=3,
        strides=1,
        padding='same',))
    model.add(tf.keras.layers.PReLU())
    model.add(tf.keras.layers.Conv2DTranspose(
        filters=filter,
        kernel_size=3,
        strides=2,
        padding='same',))
    model.add(tf.keras.layers.PReLU())

    return model

# %%
def get_unet(input_name, model_name):
    inputs = tf.keras.Input((256,256,1), name=input_name)
    
    down_1 = downsample((256,256,1), 64, 1)
    down_2 = downsample((128,128,64), 128, 2)
    down_3 = downsample((64,64,128), 256, 3)
    down_4 = downsample((32,32,256), 512, 4)

    up_1 = upsample((16,16,512), 256, 1)
    up_2 = upsample((32,32,256), 128, 2)
    up_3 = upsample((64,64,128), 64, 3)
    up_4 = upsample((128,128,64), 2, 4)

    x1 = down_1(inputs) # 128,128,64
    x2 = down_2(x1)     # 64,64,128
    x3 = down_3(x2)     # 32,32,256
    x4 = down_4(x3)     # 16,16,512

    x5 = up_1(x4)       # 32,32,256
    x5 = tf.keras.layers.Add()([x5, x3])
    x6 = up_2(x5)       # 64,64,128
    x6 = tf.keras.layers.Add()([x6, x2])
    x7 = up_3(x6)       # 128,128,64
    x7 = tf.keras.layers.Add()([x7, x1])
    x8 = up_4(x7)       # 256,256,2

    color = tf.keras.Sequential([
        tf.keras.layers.Conv2D(
            filters=2,
            kernel_size=3,
            strides=1,
            padding='same',
            activation='tanh')
    ], name="last_conv")
    color = color(x8)

    model = tf.keras.Model(inputs, color, name=model_name)
    return model

# %%
# The total colorizer
unet_total = get_unet("input_total", "unet_total")
# The instance colorizer
unet_instance = get_unet("input_instance", "unet_instance")

# %%
def loss_function(true_tensor, pred_tensor):
    absolute_error = tf.math.abs(true_tensor - pred_tensor)
    sq_error = tf.math.multiply(absolute_error, absolute_error)
    first_half = 0.5 * tf.where((absolute_error < 1.0), sq_error, tf.zeros_like(sq_error))
    place_holder = absolute_error - 0.5
    second_half = tf.where((absolute_error >= 1.0), place_holder, tf.zeros_like(place_holder))

    total = first_half + second_half
    return tf.math.reduce_mean(total)

# %%
unet_total.compile(optimizer='adam', loss=loss_function)
history_total = unet_total.fit(one_train_ds, epochs=100)

unet_total.save_weights('total')
# Out:
# Epoch 1/100
# 79/79 [==============================] - 70s 640ms/step - loss: 0.0077
# Epoch 2/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0075
# Epoch 3/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0074
# Epoch 4/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0074
# Epoch 5/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0074
# Epoch 6/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0074
# Epoch 7/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0074
# Epoch 8/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0074
# Epoch 9/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0074
# Epoch 10/100
# 79/79 [==============================] - 52s 649ms/step - loss: 0.0074
# Epoch 11/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0074
# Epoch 12/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0074
# Epoch 13/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0074
# Epoch 14/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0074
# Epoch 15/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0074
# Epoch 16/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0074
# Epoch 17/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0074
# Epoch 18/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0073
# Epoch 19/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0073
# Epoch 20/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0073
# Epoch 21/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0072
# Epoch 22/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0072
# Epoch 23/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0071
# Epoch 24/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0071
# Epoch 25/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0071
# Epoch 26/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0071
# Epoch 27/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0071
# Epoch 28/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0071
# Epoch 29/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0071
# Epoch 30/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0071
# Epoch 31/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0070
# Epoch 32/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0070
# Epoch 33/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0070
# Epoch 34/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0070
# Epoch 35/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0070
# Epoch 36/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0070
# Epoch 37/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0070
# Epoch 38/100
# 79/79 [==============================] - 50s 628ms/step - loss: 0.0069
# Epoch 39/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0069
# Epoch 40/100
# 79/79 [==============================] - 50s 628ms/step - loss: 0.0069
# Epoch 41/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0069
# Epoch 42/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0069
# Epoch 43/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0069
# Epoch 44/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0069
# Epoch 45/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0069
# Epoch 46/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0068
# Epoch 47/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0068
# Epoch 48/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0068
# Epoch 49/100
# 79/79 [==============================] - 50s 633ms/step - loss: 0.0068
# Epoch 50/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0068
# Epoch 51/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0067
# Epoch 52/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0067
# Epoch 53/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0067
# Epoch 54/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0066
# Epoch 55/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0066
# Epoch 56/100
# 79/79 [==============================] - 51s 636ms/step - loss: 0.0066
# Epoch 57/100
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0066
# Epoch 58/100
# 79/79 [==============================] - 51s 636ms/step - loss: 0.0065
# Epoch 59/100
# 79/79 [==============================] - 50s 633ms/step - loss: 0.0065
# Epoch 60/100
# 79/79 [==============================] - 50s 633ms/step - loss: 0.0065
# Epoch 61/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0064
# Epoch 62/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0064
# Epoch 63/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0064
# Epoch 64/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0063
# Epoch 65/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0062
# Epoch 66/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0062
# Epoch 67/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0062
# Epoch 68/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0061
# Epoch 69/100
# 79/79 [==============================] - 50s 628ms/step - loss: 0.0061
# Epoch 70/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0061
# Epoch 71/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0060
# Epoch 72/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0060
# Epoch 73/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0059
# Epoch 74/100
# 79/79 [==============================] - 51s 636ms/step - loss: 0.0059
# Epoch 75/100
# 79/79 [==============================] - 51s 645ms/step - loss: 0.0058
# Epoch 76/100
# 79/79 [==============================] - 51s 636ms/step - loss: 0.0058
# Epoch 77/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0057
# Epoch 78/100
# 79/79 [==============================] - 50s 634ms/step - loss: 0.0057
# Epoch 79/100
# 79/79 [==============================] - 51s 639ms/step - loss: 0.0056
# Epoch 80/100
# 79/79 [==============================] - 51s 643ms/step - loss: 0.0056
# Epoch 81/100
# 79/79 [==============================] - 51s 635ms/step - loss: 0.0056
# Epoch 82/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0056
# Epoch 83/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0055
# Epoch 84/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0055
# Epoch 85/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0055
# Epoch 86/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0054
# Epoch 87/100
# 79/79 [==============================] - 50s 633ms/step - loss: 0.0054
# Epoch 88/100
# 79/79 [==============================] - 50s 633ms/step - loss: 0.0054
# Epoch 89/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0054
# Epoch 90/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0055
# Epoch 91/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0054
# Epoch 92/100
# 79/79 [==============================] - 50s 633ms/step - loss: 0.0054
# Epoch 93/100
# 79/79 [==============================] - 50s 633ms/step - loss: 0.0053
# Epoch 94/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0053
# Epoch 95/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0052
# Epoch 96/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0052
# Epoch 97/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0051
# Epoch 98/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0050
# Epoch 99/100
# 79/79 [==============================] - 53s 665ms/step - loss: 0.0050
# Epoch 100/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0050

# %%
plt.plot(history_total.history["loss"], label="Loss")
plt.legend()
plt.show()

# %%
one_test_ds = ori_test_ds.map(preprocess_one).batch(32)

l_test, _ = next(iter(one_test_ds))
pred_ab = unet_total.predict(l_test)

pred_rgb = lab_rgb(l_test, pred_ab)

# %%
idx = np.random.choice(len(pred_rgb)-8)
fig, axes = plt.subplots(nrows=8, ncols=2, figsize=(5, 20))
[ax.axis("off") for ax in np.ravel(axes)]


for (ax_bw, ax_orig), gray_im, color_im in zip(axes, l_test[idx:idx+8], pred_rgb[idx:idx+8]):
    ax_bw.imshow(gray_im[...,0])
    ax_bw.set_title("L Image")
    
    ax_orig.imshow(color_im)
    ax_orig.set_title("Colorized Image")

# %% [markdown]
# ## Second Stage
# In the second stage we will be working with the instances. The same architecture will be use to fine tune on the instances but we will need to change the dataset that we use in this stage.
#
# The dataset:
# - Needs to have instances from the total image -- We will be doing one instance for the time being
# - The architecture is the same
# - Loss is the same

# %%
def preprocess_two(element):
    image = element['image']
    boxes = element['objects']['bbox']
    index = tf.random.uniform((1,), 0, len(boxes), dtype=tf.int32)[0]
    box = boxes[index]

    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, (256,256))
    
    ymin = tf.cast(tf.math.round(box[0] * 256), dtype=tf.int32)
    xmin = tf.cast(tf.math.round(box[1] * 256), dtype=tf.int32)
    ymax = tf.cast(tf.math.round(box[2] * 256), dtype=tf.int32)
    xmax = tf.cast(tf.math.round(box[3] * 256), dtype=tf.int32)

    image = tf.image.crop_to_bounding_box(
        image,
        ymin,
        xmin,
        ymax - ymin,
        xmax - xmin)

    image = tf.image.resize(image, (256,256))
    lab = tfio.experimental.color.rgb_to_lab(image)
    l = lab[...,0]/50.0 - 1.0
    ab = lab[...,1:]/110.0
    
    l = tf.expand_dims(l, axis=-1)

    return l, ab

# %%
two_train_ds = ori_train_ds.map(preprocess_two).batch(32)

l_batch, ab_batch = next(iter(two_train_ds))
print(l_batch.shape)
print(ab_batch.shape)
# Out:
# (32, 256, 256, 1)
# (32, 256, 256, 2)

# %%
print("L Space")
print(f"  [SHAPE]: {l_batch.shape}")
print(f"  [MIN]:{tf.math.reduce_min(l_batch)}")
print(f"  [MEAN]:{tf.math.reduce_mean(l_batch)}")
print(f"  [MAX]:{tf.math.reduce_max(l_batch)}")


print("ab Space")
print(f"  [SHAPE]: {ab_batch.shape}")
print(f"  [MIN]:{tf.math.reduce_min(ab_batch)}")
print(f"  [MEAN]:{tf.math.reduce_mean(ab_batch)}")
print(f"  [MAX]:{tf.math.reduce_max(ab_batch)}")
# Out:
# L Space
#   [SHAPE]: (32, 256, 256, 1)
#   [MIN]:-1.0
#   [MEAN]:-0.16836126148700714
#   [MAX]:1.0
# ab Space
#   [SHAPE]: (32, 256, 256, 2)
#   [MIN]:-0.5682538747787476
#   [MEAN]:0.04209483787417412
#   [MAX]:0.8262012004852295

# %%
# build a model and then take the weights of the previous model
unet_instance.load_weights('total')

# %%
opt = tf.keras.optimizers.Adam(learning_rate=1e-5)
loss_fn = loss_function

unet_instance.compile(optimizer=opt, loss=loss_fn)
history_instance = unet_instance.fit(two_train_ds, epochs=100)
# Out:
# Epoch 1/100
# 79/79 [==============================] - 52s 605ms/step - loss: 0.0072
# Epoch 2/100
# 79/79 [==============================] - 48s 603ms/step - loss: 0.0069
# Epoch 3/100
# 79/79 [==============================] - 48s 608ms/step - loss: 0.0070
# Epoch 4/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0067
# Epoch 5/100
# 79/79 [==============================] - 48s 608ms/step - loss: 0.0068
# Epoch 6/100
# 79/79 [==============================] - 48s 602ms/step - loss: 0.0068
# Epoch 7/100
# 79/79 [==============================] - 49s 610ms/step - loss: 0.0068
# Epoch 8/100
# 79/79 [==============================] - 48s 603ms/step - loss: 0.0068
# Epoch 9/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0068
# Epoch 10/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0068
# Epoch 11/100
# 79/79 [==============================] - 49s 610ms/step - loss: 0.0066
# Epoch 12/100
# 79/79 [==============================] - 50s 633ms/step - loss: 0.0067
# Epoch 13/100
# 79/79 [==============================] - 49s 618ms/step - loss: 0.0066
# Epoch 14/100
# 79/79 [==============================] - 48s 606ms/step - loss: 0.0065
# Epoch 15/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0066
# Epoch 16/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0064
# Epoch 17/100
# 79/79 [==============================] - 49s 612ms/step - loss: 0.0066
# Epoch 18/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0065
# Epoch 19/100
# 79/79 [==============================] - 49s 609ms/step - loss: 0.0064
# Epoch 20/100
# 79/79 [==============================] - 49s 615ms/step - loss: 0.0065
# Epoch 21/100
# 79/79 [==============================] - 49s 612ms/step - loss: 0.0064
# Epoch 22/100
# 79/79 [==============================] - 49s 611ms/step - loss: 0.0063
# Epoch 23/100
# 79/79 [==============================] - 49s 610ms/step - loss: 0.0063
# Epoch 24/100
# 79/79 [==============================] - 49s 609ms/step - loss: 0.0065
# Epoch 25/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0063
# Epoch 26/100
# 79/79 [==============================] - 48s 606ms/step - loss: 0.0062
# Epoch 27/100
# 79/79 [==============================] - 48s 606ms/step - loss: 0.0063
# Epoch 28/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0062
# Epoch 29/100
# 79/79 [==============================] - 48s 604ms/step - loss: 0.0061
# Epoch 30/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0062
# Epoch 31/100
# 79/79 [==============================] - 49s 611ms/step - loss: 0.0062
# Epoch 32/100
# 79/79 [==============================] - 48s 602ms/step - loss: 0.0062
# Epoch 33/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0061
# Epoch 34/100
# 79/79 [==============================] - 48s 603ms/step - loss: 0.0062
# Epoch 35/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0061
# Epoch 36/100
# 79/79 [==============================] - 48s 606ms/step - loss: 0.0061
# Epoch 37/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0060
# Epoch 38/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0062
# Epoch 39/100
# 79/79 [==============================] - 48s 606ms/step - loss: 0.0059
# Epoch 40/100
# 79/79 [==============================] - 48s 604ms/step - loss: 0.0059
# Epoch 41/100
# 79/79 [==============================] - 48s 604ms/step - loss: 0.0059
# Epoch 42/100
# 79/79 [==============================] - 48s 609ms/step - loss: 0.0059
# Epoch 43/100
# 79/79 [==============================] - 49s 612ms/step - loss: 0.0058
# Epoch 44/100
# 79/79 [==============================] - 49s 613ms/step - loss: 0.0059
# Epoch 45/100
# 79/79 [==============================] - 50s 624ms/step - loss: 0.0059
# Epoch 46/100
# 79/79 [==============================] - 50s 623ms/step - loss: 0.0059
# Epoch 47/100
# 79/79 [==============================] - 50s 624ms/step - loss: 0.0059
# Epoch 48/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0058
# Epoch 49/100
# 79/79 [==============================] - 49s 616ms/step - loss: 0.0058
# Epoch 50/100
# 79/79 [==============================] - 50s 628ms/step - loss: 0.0059
# Epoch 51/100
# 79/79 [==============================] - 49s 615ms/step - loss: 0.0059
# Epoch 52/100
# 79/79 [==============================] - 49s 614ms/step - loss: 0.0058
# Epoch 53/100
# 79/79 [==============================] - 50s 623ms/step - loss: 0.0058
# Epoch 54/100
# 79/79 [==============================] - 50s 622ms/step - loss: 0.0058
# Epoch 55/100
# 79/79 [==============================] - 50s 622ms/step - loss: 0.0059
# Epoch 56/100
# 79/79 [==============================] - 50s 621ms/step - loss: 0.0058
# Epoch 57/100
# 79/79 [==============================] - 49s 620ms/step - loss: 0.0059
# Epoch 58/100
# 79/79 [==============================] - 50s 622ms/step - loss: 0.0058
# Epoch 59/100
# 79/79 [==============================] - 49s 621ms/step - loss: 0.0058
# Epoch 60/100
# 79/79 [==============================] - 50s 623ms/step - loss: 0.0058
# Epoch 61/100
# 79/79 [==============================] - 49s 619ms/step - loss: 0.0057
# Epoch 62/100
# 79/79 [==============================] - 49s 620ms/step - loss: 0.0058
# Epoch 63/100
# 79/79 [==============================] - 49s 618ms/step - loss: 0.0056
# Epoch 64/100
# 79/79 [==============================] - 50s 622ms/step - loss: 0.0058
# Epoch 65/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0057
# Epoch 66/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0057
# Epoch 67/100
# 79/79 [==============================] - 50s 622ms/step - loss: 0.0056
# Epoch 68/100
# 79/79 [==============================] - 50s 627ms/step - loss: 0.0057
# Epoch 69/100
# 79/79 [==============================] - 50s 632ms/step - loss: 0.0055
# Epoch 70/100
# 79/79 [==============================] - 51s 634ms/step - loss: 0.0056
# Epoch 71/100
# 79/79 [==============================] - 50s 630ms/step - loss: 0.0056
# Epoch 72/100
# 79/79 [==============================] - 50s 631ms/step - loss: 0.0055
# Epoch 73/100
# 79/79 [==============================] - 50s 626ms/step - loss: 0.0055
# Epoch 74/100
# 79/79 [==============================] - 50s 629ms/step - loss: 0.0054
# Epoch 75/100
# 79/79 [==============================] - 51s 636ms/step - loss: 0.0055
# Epoch 76/100
# 79/79 [==============================] - 49s 615ms/step - loss: 0.0054
# Epoch 77/100
# 79/79 [==============================] - 49s 614ms/step - loss: 0.0055
# Epoch 78/100
# 79/79 [==============================] - 48s 606ms/step - loss: 0.0055
# Epoch 79/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0054
# Epoch 80/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0054
# Epoch 81/100
# 79/79 [==============================] - 48s 606ms/step - loss: 0.0054
# Epoch 82/100
# 79/79 [==============================] - 49s 609ms/step - loss: 0.0054
# Epoch 83/100
# 79/79 [==============================] - 48s 608ms/step - loss: 0.0055
# Epoch 84/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0055
# Epoch 85/100
# 79/79 [==============================] - 48s 606ms/step - loss: 0.0055
# Epoch 86/100
# 79/79 [==============================] - 49s 610ms/step - loss: 0.0055
# Epoch 87/100
# 79/79 [==============================] - 48s 604ms/step - loss: 0.0055
# Epoch 88/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0055
# Epoch 89/100
# 79/79 [==============================] - 48s 603ms/step - loss: 0.0054
# Epoch 90/100
# 79/79 [==============================] - 48s 608ms/step - loss: 0.0053
# Epoch 91/100
# 79/79 [==============================] - 48s 601ms/step - loss: 0.0052
# Epoch 92/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0052
# Epoch 93/100
# 79/79 [==============================] - 48s 603ms/step - loss: 0.0053
# Epoch 94/100
# 79/79 [==============================] - 48s 606ms/step - loss: 0.0052
# Epoch 95/100
# 79/79 [==============================] - 48s 607ms/step - loss: 0.0052
# Epoch 96/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0052
# Epoch 97/100
# 79/79 [==============================] - 48s 605ms/step - loss: 0.0052
# Epoch 98/100
# 79/79 [==============================] - 48s 608ms/step - loss: 0.0052
# Epoch 99/100
# 79/79 [==============================] - 49s 614ms/step - loss: 0.0052
# Epoch 100/100
# 79/79 [==============================] - 50s 628ms/step - loss: 0.0052

# %%
plt.plot(history_instance.history["loss"], label="Loss")
plt.legend()
plt.show()

# %%
two_test_ds = ori_test_ds.map(preprocess_two).batch(32)

l_test, _ = next(iter(two_test_ds))
pred_ab = unet_instance.predict(l_test)

pred_rgb = lab_rgb(l_test, pred_ab)

# %%
idx = np.random.choice(len(pred_rgb)-8)
fig, axes = plt.subplots(nrows=8, ncols=2, figsize=(5, 20))
[ax.axis("off") for ax in np.ravel(axes)]


for (ax_bw, ax_orig), gray_im, color_im in zip(axes, l_test[idx:idx+8], pred_rgb[idx:idx+8]):
    ax_bw.imshow(gray_im[...,0])
    ax_bw.set_title("L Image")
    
    ax_orig.imshow(color_im)
    ax_orig.set_title("Colorized Image")

# %% [markdown]
# ## Fusion Model

# %%
def preprocess_three(element):
    image = element['image']
    boxes = element['objects']['bbox']
    index = tf.random.uniform((1,), 0, len(boxes), dtype=tf.int32)[0]
    box = boxes[index]

    image = tf.image.convert_image_dtype(image, tf.float32)
    image = tf.image.resize(image, (256,256))
    ori_lab = tfio.experimental.color.rgb_to_lab(image)
    ori_l = ori_lab[...,0]/50.0 - 1.0
    ori_ab = ori_lab[...,1:]/110.0

    ori_l = tf.expand_dims(ori_l, axis=-1)
    
    ymin = tf.cast(tf.math.round(box[0] * 256), dtype=tf.int32)
    xmin = tf.cast(tf.math.round(box[1] * 256), dtype=tf.int32)
    ymax = tf.cast(tf.math.round(box[2] * 256), dtype=tf.int32)
    xmax = tf.cast(tf.math.round(box[3] * 256), dtype=tf.int32)

    image = tf.image.crop_to_bounding_box(
        image,
        ymin,
        xmin,
        ymax - ymin,
        xmax - xmin)

    image = tf.image.resize(image, (256,256))
    crop_lab = tfio.experimental.color.rgb_to_lab(image)
    crop_l = crop_lab[...,0]/50.0 - 1.0
    crop_ab = crop_lab[...,1:]/110.0
    
    crop_l = tf.expand_dims(crop_l, axis=-1)

    return {"ori_l": ori_l, "crop_l": crop_l, "box": box}, ori_ab

# %%
three_train_ds = ori_train_ds.map(preprocess_three).batch(1)

inputs, ori_ab = next(iter(three_train_ds))
print(inputs["ori_l"].shape)
print(inputs["crop_l"].shape)
print(inputs["box"].shape)
print(ori_ab.shape)
# Out:
# (1, 256, 256, 1)
# (1, 256, 256, 1)
# (1, 4)
# (1, 256, 256, 2)

# %%
# Save the blocks
layer_names = [
    "downsample_1",
    "downsample_2",
    "downsample_3",
    "downsample_4",
    "upsample_1",
    "upsample_2",
    "upsample_3",
    "upsample_4",
    "last_conv"
]

for name in layer_names:
    unet_total.get_layer(name).save_weights(f"total/{name}")
    unet_instance.get_layer(name).save_weights(f"instance/{name}")

# %%
def resize_pad(i, w_i, box, s_shape):
    # i.shape == H, W, C
    # w_i.shape == H, W, C
    # box.shape == 4,

    ymin = tf.cast(tf.math.round(box[0][0] * s_shape), dtype=tf.int32)
    xmin = tf.cast(tf.math.round(box[0][1] * s_shape), dtype=tf.int32)
    ymax = tf.cast(tf.math.round(box[0][2] * s_shape), dtype=tf.int32)
    xmax = tf.cast(tf.math.round(box[0][3] * s_shape), dtype=tf.int32)

    height = tf.maximum(tf.math.abs(ymax - ymin), 1)
    width =  tf.maximum(tf.math.abs(xmax - xmin), 1)

    ymin = tf.minimum(tf.math.abs(s_shape - height), ymin)
    xmin = tf.minimum(tf.math.abs(s_shape - width), xmin)

    i_resize = tf.image.resize(i, (height, width))
    i_pad = tf.image.pad_to_bounding_box(
        i_resize,
        ymin,
        xmin,
        s_shape,
        s_shape
    ) # 1, H, W, C


    wi_resize = tf.image.resize(w_i, (height, width))
    wi_pad = tf.image.pad_to_bounding_box(
        wi_resize,
        ymin,
        xmin,
        s_shape,
        s_shape
    ) # 1, H, W, C


    return i_pad, wi_pad

# %%
def fusion_block(t, i, channels, s_shape, box):
    # t.shape == H, W, C
    # i.shape == H, W, C

    conv_t = tf.keras.Sequential(
        [
         tf.keras.layers.Conv2D(channels, 3, padding='same', activation='relu'),
         tf.keras.layers.Conv2D(channels, 3, padding='same', activation='relu'),
         tf.keras.layers.Conv2D(channels, 3, padding='same', activation='relu'),
        ]
    )

    conv_i = tf.keras.Sequential(
        [
         tf.keras.layers.Conv2D(channels, 3, padding='same', activation='relu'),
         tf.keras.layers.Conv2D(channels, 3, padding='same', activation='relu'),
         tf.keras.layers.Conv2D(channels, 3, padding='same', activation='relu'),
        ]
    )

    w_t = conv_t(t) # H, W, C
    w_i = conv_i(i) # H, W, C

    # Resize and Pad w_i and i
    i, w_i = resize_pad(i, w_i, box, s_shape)

    features = tf.stack([t, i], axis=0)
    weights = tf.stack([w_t, w_i], axis=0)
    soft_weights = tf.math.softmax(weights, axis=0)

    out = tf.math.multiply(features, soft_weights)
    out = tf.math.reduce_sum(out, axis=0)

    return out

# %%
def get_fusion_model():
    # Build the entire fusion model

    inputs_t = tf.keras.Input((256, 256, 1), name="ori_l")    # 256, 256, 1
    inputs_i = tf.keras.Input((256, 256, 1), name="crop_l")   # 256, 256, 1
    bbox = tf.keras.Input((4,), name="box")                      # 4,
    
    # downsample_1
    down_t1 = downsample((256,256,1), 64, 1)
    down_t1.load_weights('total/downsample_1')
    down_t1.trainable=False
    t1 = down_t1(inputs_t)
    down_i1 = downsample((256,256,1), 64, 2)
    down_i1.load_weights('instance/downsample_1')
    down_i1.trainable=False
    i1 = down_i1(inputs_i)
    f1 = fusion_block(t1, i1, 64, 128, bbox)

    # downsample_2
    down_t2 = downsample((128,128,64), 128, 3)
    down_t2.load_weights('total/downsample_2')
    down_t2.trainable=False
    t2 = down_t2(f1)
    down_i2 = downsample((128,128,64), 128, 4)
    down_i2.load_weights('instance/downsample_2')
    down_i2.trainable=False
    i2 = down_i2(i1)
    f2 = fusion_block(t2, i2, 128, 64, bbox)


    # downsample_3
    down_t3 = downsample((64,64,128), 256, 5)
    down_t3.load_weights('total/downsample_3')
    down_t3.trainable=False
    t3 = down_t3(f2)
    down_i3 = downsample((64,64,128), 256, 6)
    down_i3.load_weights('instance/downsample_3')
    down_i3.trainable=False
    i3 = down_i3(i2)
    f3 = fusion_block(t3, i3, 256, 32, bbox)
    

    # downsample_4
    down_t4 = downsample((32,32,256), 512, 7)
    down_t4.load_weights('total/downsample_4')
    down_t4.trainable=False
    t4 = down_t4(f3)
    down_i4 = downsample((32,32,256), 512, 8)
    down_i4.load_weights('instance/downsample_4')
    down_i4.trainable=False
    i4 = down_i4(i3)
    f4 = fusion_block(t4, i4, 512, 16, bbox)


    # upsample_1
    up_t1 = upsample((16,16,512), 256, 1)
    up_t1.load_weights('total/upsample_1')
    up_t1.trainable=False
    t5 = up_t1(f4)
    up_i1 = upsample((16,16,512), 256, 2)
    up_i1.load_weights('instance/upsample_1')
    up_i1.trainable=False
    i5 = up_i1(i4)
    f5 = fusion_block(t5, i5, 256, 32, bbox)
    f5 = tf.keras.layers.Add()([f5, f3])

    # upsample_2
    up_t2 = upsample((32,32,256), 128, 3)
    up_t2.load_weights('total/upsample_2')
    up_t2.trainable=False
    t6 = up_t2(f5)
    up_i2 = upsample((32,32,256), 128, 4)
    up_i2.load_weights('instance/upsample_2')
    up_i2.trainable=False
    i6 = up_i2(i5)
    f6 = fusion_block(t6, i6, 128, 64, bbox)
    f6 = tf.keras.layers.Add()([f6, f2])


    # upsample_3
    up_t3 = upsample((64,64,128), 64, 5)
    up_t3.load_weights('total/upsample_3')
    up_t3.trainable=False
    t7 = up_t3(f6)
    up_i3 = upsample((64,64,128), 64, 6)
    up_i3.load_weights('instance/upsample_3')
    up_i3.trainable=False
    i7 = up_i3(i6)
    f7 = fusion_block(t7, i7, 64, 128, bbox)
    f7 = tf.keras.layers.Add()([f7, f1])


    # upsample_4
    up_t4 = upsample((128,128,64), 2, 7)
    up_t4.load_weights('total/upsample_4')
    up_t4.trainable=False
    t8 = up_t4(f7)
    up_i4 = upsample((128,128,64), 2, 8)
    up_i4.load_weights('instance/upsample_4')
    up_i4.trainable=False
    i8 = up_i4(i7)
    f8 = fusion_block(t8, i8, 2, 256, bbox)

    color = tf.keras.Sequential([
        tf.keras.layers.Conv2D(
            filters=2,
            kernel_size=3,
            strides=1,
            padding='same',
            activation='tanh')])
    color.load_weights("total/last_conv")
    color.trainable = False
    color = color(f8)

    model = tf.keras.Model(inputs=[inputs_t, inputs_i, bbox], outputs=[color])
    return model

# %%
fusion_model = get_fusion_model()
fusion_model.compile(optimizer='adam', loss=loss_fn)

# %%
history_fusion = fusion_model.fit(three_train_ds, epochs=50)
# Out:
# Epoch 1/50
# 2501/2501 [==============================] - 196s 75ms/step - loss: 0.0058
# Epoch 2/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 3/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 4/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 5/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0056
# Epoch 6/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 7/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 8/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 9/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 10/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 11/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 12/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0056
# Epoch 13/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 14/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 15/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 16/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 17/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 18/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 19/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 20/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 21/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 22/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 23/50
# 2501/2501 [==============================] - 186s 74ms/step - loss: 0.0055
# Epoch 24/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 25/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 26/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 27/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 28/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0055
# Epoch 29/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 30/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0055
# Epoch 31/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0054
# Epoch 32/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0054
# Epoch 33/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0054
# Epoch 34/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 35/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 36/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 37/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0054
# Epoch 38/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0054
# Epoch 39/50
# 2501/2501 [==============================] - 189s 75ms/step - loss: 0.0054
# Epoch 40/50
# 2501/2501 [==============================] - 189s 75ms/step - loss: 0.0054
# Epoch 41/50
# 2501/2501 [==============================] - 189s 75ms/step - loss: 0.0054
# Epoch 42/50
# 2501/2501 [==============================] - 187s 75ms/step - loss: 0.0054
# Epoch 43/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 44/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 45/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 46/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 47/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 48/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 49/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054
# Epoch 50/50
# 2501/2501 [==============================] - 188s 75ms/step - loss: 0.0054

# %%
plt.plot(history_fusion.history["loss"], label="Loss")
plt.legend()
plt.show()

# %%
three_test_ds = ori_test_ds.map(preprocess_three).batch(1)

# %%
fig, axes = plt.subplots(nrows=8, ncols=2, figsize=(5, 20))
[ax.axis("off") for ax in np.ravel(axes)]


for ((inputs, ori_ab), (ax_bw, ax_orig)) in zip(three_test_ds.take(8), axes):
    ax_bw.imshow(inputs["ori_l"][0,...,0])
    ax_bw.set_title("L Image")
    
    pred_ab = fusion_model.predict([inputs["ori_l"], inputs["crop_l"], inputs["box"]])
    rgb = lab_rgb(inputs["ori_l"], pred_ab)
    ax_orig.imshow(rgb[0])
    ax_orig.set_title("Colorized Image")
